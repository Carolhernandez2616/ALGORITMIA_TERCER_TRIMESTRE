# %% [markdown]
# <a href="https://colab.research.google.com/github/Carolhernandez2616/ALGORITMIA_TERCER_TRIMESTRE/blob/main/PRENDAS_AGREGADAS_LISTAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#INVENTARIO DE UNA FERRETERIA
#SIMULAR EL CONTROL DEL INVENTARIO BASICO
#agregar productos
#insertar productos
#elimiinar productos, -remove(), pop()
#ordenar productos alfabeticamente  .sort()
#invertir valores de presentacion .reverse()


def mostrar_inventario(productos):
    print("\nMOSTRAR INVENTARIO ACTUAL\n")
    if not productos:
        print("NO HAY PRODUCTOS REGISTRADOS")
        return
    for i, producto in enumerate(productos, start=1):
        print(f"{i} - {producto ['nombre']} - ${producto['precio']:.2f}")
def agregar_producto(productos, nombre, precio):
    #Validacion de la entrada de los datos a la lista
    if isinstance(nombre, str) and nombre.strip() and isinstance(precio, (int,float)) and precio > 0:
        productos.append({"nombre": nombre.title(), "precio": precio})
    else:
        print("DATOS INVALIDOS , EL NOMBRE DEBE SER TEXTO Y NO VACIO Y EL PRECIO NUMERO POSITIVO")

def main():
    inventario = [
        {"nombre": "TALADRO","precio": 150000},
        {"nombre": "MARTILLO","precio": 155788000},
        {"nombre": "DESTORNILLADOR","precio": 147840000}
    ]
    mostrar_inventario(inventario)

if __name__ == "__main__":
    main()
# Out:
# MOSTRAR INVENTARIO ACTUAL
#
# 1 - TALADRO - $150000.00
# 2 - MARTILLO - $155788000.00
# 3 - DESTORNILLADOR - $147840000.00

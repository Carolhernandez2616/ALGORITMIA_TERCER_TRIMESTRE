# %% [markdown]
# <a href="https://colab.research.google.com/github/Carolhernandez2616/ALGORITMIA_TERCER_TRIMESTRE/blob/main/PERRO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class perro:
    def __init__(self, Raza, Color, Edad, Tamaño):
        self.Raza = Raza
        self.Color = Color
        self.Edad = Edad
        self.Tamaño = Tamaño

    def mostrar__info(self):
        print(f"La raza del perro es: {self.Raza}")
        print(f"El color del perro es: {self.Color}")
        print(f"La edad del perro es: {self.Edad}")
        print(f"El tamaño del perro es: {self.Tamaño}")

def main():
    Raza = input("Ingrese la raza del perro: ")
    Color = input("Ingrese el color del perro: ")
    Edad = input("Ingrese la edad del perro: ")
    Tamaño = input("Ingrese el tamaño del perro: ")
    perro1 = perro(Raza, Color, Edad, Tamaño)


if __name__ == "__main__":
    main()
# Out:
# Ingrese la raza del perro: NEGRO
# Ingrese el color del perro: RUBIO
# Ingrese la edad del perro: 10
# Ingrese el tamaño del perro: 3
